# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#! pip install matplotlib
#! pip install scipy
#! pip install response

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#perform API calls to check the weather of each city in our list


#OpenWeather Key

units = "imperial"

query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=e1c264e97c2d34a3be608ce956ffed68&units=imperial&q=

# %%
#Create a dataframe to store the data
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print (city)
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | nalut
# Processing Record 3 of Set 1 | hasaki
# Processing Record 4 of Set 1 | victoria
# Processing Record 5 of Set 1 | pangody
# Processing Record 6 of Set 1 | burns lake
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | lianran
# Processing Record 9 of Set 1 | santander
# Processing Record 10 of Set 1 | souillac
# Processing Record 11 of Set 1 | aurora
# Processing Record 12 of Set 1 | sereflikochisar
# saleaula
# City not found. Skipping...
# Processing Record 13 of Set 1 | puerto escondido
# Processing Record 14 of Set 1 | saskylakh
# taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | palmeiras de goias
# Processing Record 16 of Set 1 | hofn
# Processing Record 17 of Set 1 | gornopravdinsk
# Processing Record 18 of Set 1 | ratnagiri
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | nata
# belushya guba
# City not found. Skipping...
# illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | korla
# palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 1 | faanui
# Processing Record 27 of Set 1 | killybegs
# Processing Record 28 of Set 1 | ler
# Processing Record 29 of Set 1 | richards bay
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | vuktyl
# Processing Record 33 of Set 1 | pirovskoye
# ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 1 | yar-sale
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | saldanha
# Processing Record 38 of Set 1 | lata
# Processing Record 39 of Set 1 | chavantes
# Processing Record 40 of Set 1 | pisco
# Processing Record 41 of Set 1 | poltavka
# Processing Record 42 of Set 1 | port blair
# Processing Record 43 of Set 1 | airai
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | tual
# Processing Record 47 of Set 1 | sakakah
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | porosozero
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | beloha
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | saint-philippe
# karaul
# City not found. Skipping...
# Processing Record 7 of Set 2 | rehoboth
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | mastic beach
# Processing Record 10 of Set 2 | homer
# Processing Record 11 of Set 2 | emerald
# Processing Record 12 of Set 2 | kemijarvi
# sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 2 | martapura
# Processing Record 14 of Set 2 | kaitangata
# Processing Record 15 of Set 2 | rikitea
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | klaksvik
# Processing Record 18 of Set 2 | ahipara
# Processing Record 19 of Set 2 | boa vista
# Processing Record 20 of Set 2 | leningradskiy
# Processing Record 21 of Set 2 | ancud
# Processing Record 22 of Set 2 | east london
# attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | minab
# Processing Record 27 of Set 2 | cayenne
# Processing Record 28 of Set 2 | ampanihy
# Processing Record 29 of Set 2 | scarborough
# Processing Record 30 of Set 2 | jumla
# Processing Record 31 of Set 2 | kajaani
# Processing Record 32 of Set 2 | provideniya
# Processing Record 33 of Set 2 | pucallpa
# Processing Record 34 of Set 2 | adiake
# bokspits
# City not found. Skipping...
# Processing Record 35 of Set 2 | algiers
# Processing Record 36 of Set 2 | san patricio
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | vernon
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | juneau
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | ponta do sol
# Processing Record 43 of Set 2 | kudahuvadhoo
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | barrow
# Processing Record 46 of Set 2 | kautokeino
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | vrangel
# Processing Record 1 of Set 3 | lufilufi
# Processing Record 2 of Set 3 | terme
# Processing Record 3 of Set 3 | rocha
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | sao felix do xingu
# Processing Record 6 of Set 3 | dodge city
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | berlevag
# Processing Record 9 of Set 3 | jinchang
# Processing Record 10 of Set 3 | sao joao da barra
# Processing Record 11 of Set 3 | port elizabeth
# achisay
# City not found. Skipping...
# Processing Record 12 of Set 3 | alugan
# Processing Record 13 of Set 3 | havre-saint-pierre
# Processing Record 14 of Set 3 | beitbridge
# Processing Record 15 of Set 3 | lompoc
# Processing Record 16 of Set 3 | oistins
# Processing Record 17 of Set 3 | aklavik
# Processing Record 18 of Set 3 | hobart
# Processing Record 19 of Set 3 | cochrane
# Processing Record 20 of Set 3 | laguna
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | muros
# Processing Record 23 of Set 3 | sungaipenuh
# Processing Record 24 of Set 3 | grindavik
# Processing Record 25 of Set 3 | lagoa
# Processing Record 26 of Set 3 | talnakh
# Processing Record 27 of Set 3 | iqaluit
# Processing Record 28 of Set 3 | uige
# Processing Record 29 of Set 3 | itatiaia
# Processing Record 30 of Set 3 | new richmond
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | port moresby
# Processing Record 33 of Set 3 | yaan
# Processing Record 34 of Set 3 | kahului
# Processing Record 35 of Set 3 | aguas vermelhas
# Processing Record 36 of Set 3 | road town
# Processing Record 37 of Set 3 | olafsvik
# Processing Record 38 of Set 3 | nyahururu
# Processing Record 39 of Set 3 | torrijos
# Processing Record 40 of Set 3 | hilo
# Processing Record 41 of Set 3 | pevek
# Processing Record 42 of Set 3 | varzea da palma
# Processing Record 43 of Set 3 | grenville
# Processing Record 44 of Set 3 | cidreira
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | great yarmouth
# Processing Record 47 of Set 3 | denpasar
# barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 3 | lerwick
# Processing Record 49 of Set 3 | keuruu
# Processing Record 1 of Set 4 | tura
# Processing Record 2 of Set 4 | maamba
# Processing Record 3 of Set 4 | vardo
# Processing Record 4 of Set 4 | wiarton
# Processing Record 5 of Set 4 | langsa
# Processing Record 6 of Set 4 | nanortalik
# tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 4 | bekhtery
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | naze
# Processing Record 10 of Set 4 | castro
# Processing Record 11 of Set 4 | belturbet
# Processing Record 12 of Set 4 | matara
# Processing Record 13 of Set 4 | praia da vitoria
# Processing Record 14 of Set 4 | norman wells
# Processing Record 15 of Set 4 | serenje
# Processing Record 16 of Set 4 | mahebourg
# Processing Record 17 of Set 4 | atar
# Processing Record 18 of Set 4 | arraial do cabo
# Processing Record 19 of Set 4 | vaihingen
# Processing Record 20 of Set 4 | palmer
# Processing Record 21 of Set 4 | baranchinskiy
# Processing Record 22 of Set 4 | kavieng
# Processing Record 23 of Set 4 | maputo
# Processing Record 24 of Set 4 | muli
# Processing Record 25 of Set 4 | kibala
# Processing Record 26 of Set 4 | prata
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | tessalit
# amderma
# City not found. Skipping...
# andevoranto
# City not found. Skipping...
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | mayo
# Processing Record 31 of Set 4 | manali
# Processing Record 32 of Set 4 | safranbolu
# Processing Record 33 of Set 4 | vaini
# Processing Record 34 of Set 4 | sao filipe
# Processing Record 35 of Set 4 | digby
# Processing Record 36 of Set 4 | raudeberg
# Processing Record 37 of Set 4 | chaplygin
# Processing Record 38 of Set 4 | bengkulu
# Processing Record 39 of Set 4 | qaanaaq
# Processing Record 40 of Set 4 | tolyatti
# Processing Record 41 of Set 4 | panzhihua
# Processing Record 42 of Set 4 | mabaruma
# Processing Record 43 of Set 4 | dicabisagan
# nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 4 | belmonte
# Processing Record 45 of Set 4 | novyy yarychiv
# Processing Record 46 of Set 4 | port augusta
# Processing Record 47 of Set 4 | statesboro
# Processing Record 48 of Set 4 | flinders
# Processing Record 49 of Set 4 | torbay
# Processing Record 1 of Set 5 | shepsi
# Processing Record 2 of Set 5 | ukiah
# Processing Record 3 of Set 5 | black forest
# Processing Record 4 of Set 5 | cairns
# Processing Record 5 of Set 5 | la rioja
# Processing Record 6 of Set 5 | rio gallegos
# Processing Record 7 of Set 5 | shimoda
# Processing Record 8 of Set 5 | dingzhou
# Processing Record 9 of Set 5 | sept-iles
# Processing Record 10 of Set 5 | ostrovnoy
# Processing Record 11 of Set 5 | chhindwara
# Processing Record 12 of Set 5 | abha
# Processing Record 13 of Set 5 | passo de camaragibe
# Processing Record 14 of Set 5 | betioky
# Processing Record 15 of Set 5 | yashkul
# Processing Record 16 of Set 5 | tuktoyaktuk
# Processing Record 17 of Set 5 | majene
# Processing Record 18 of Set 5 | ordynskoye
# Processing Record 19 of Set 5 | san vicente
# Processing Record 20 of Set 5 | karratha
# Processing Record 21 of Set 5 | ormara
# Processing Record 22 of Set 5 | curitibanos
# Processing Record 23 of Set 5 | lebu
# Processing Record 24 of Set 5 | vila velha
# Processing Record 25 of Set 5 | vila
# Processing Record 26 of Set 5 | half moon bay
# Processing Record 27 of Set 5 | shahdadkot
# Processing Record 28 of Set 5 | asfi
# Processing Record 29 of Set 5 | dumai
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | gedo
# Processing Record 32 of Set 5 | jardim
# Processing Record 33 of Set 5 | nortelandia
# Processing Record 34 of Set 5 | enderby
# Processing Record 35 of Set 5 | kawalu
# Processing Record 36 of Set 5 | pacifica
# Processing Record 37 of Set 5 | snasa
# Processing Record 38 of Set 5 | dikson
# Processing Record 39 of Set 5 | banepa
# Processing Record 40 of Set 5 | ajdabiya
# Processing Record 41 of Set 5 | harper
# Processing Record 42 of Set 5 | rawson
# Processing Record 43 of Set 5 | sitka
# Processing Record 44 of Set 5 | dublin
# Processing Record 45 of Set 5 | kuusamo
# Processing Record 46 of Set 5 | beinamar
# Processing Record 47 of Set 5 | aswan
# Processing Record 48 of Set 5 | san joaquin
# temaraia
# City not found. Skipping...
# Processing Record 49 of Set 5 | krasnoselkup
# Processing Record 1 of Set 6 | lavrentiya
# Processing Record 2 of Set 6 | heishan
# Processing Record 3 of Set 6 | alofi
# Processing Record 4 of Set 6 | thinadhoo
# Processing Record 5 of Set 6 | mujiayingzi
# Processing Record 6 of Set 6 | bira
# Processing Record 7 of Set 6 | hargeysa
# Processing Record 8 of Set 6 | nikolskoye
# Processing Record 9 of Set 6 | vostok
# Processing Record 10 of Set 6 | ballina
# Processing Record 11 of Set 6 | adrar
# Processing Record 12 of Set 6 | zabid
# Processing Record 13 of Set 6 | tairua
# Processing Record 14 of Set 6 | kavaratti
# Processing Record 15 of Set 6 | severodvinsk
# Processing Record 16 of Set 6 | syumsi
# Processing Record 17 of Set 6 | caravelas
# Processing Record 18 of Set 6 | olga
# Processing Record 19 of Set 6 | praya
# tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 6 | broome
# Processing Record 21 of Set 6 | coquimbo
# Processing Record 22 of Set 6 | narsaq
# Processing Record 23 of Set 6 | parker
# Processing Record 24 of Set 6 | irbil
# khormuj
# City not found. Skipping...
# Processing Record 25 of Set 6 | vredendal
# Processing Record 26 of Set 6 | horodnya
# Processing Record 27 of Set 6 | nome
# Processing Record 28 of Set 6 | padang
# Processing Record 29 of Set 6 | saint george
# Processing Record 30 of Set 6 | biloela
# Processing Record 31 of Set 6 | grand-lahou
# warqla
# City not found. Skipping...
# Processing Record 32 of Set 6 | keti bandar
# Processing Record 33 of Set 6 | walvis bay
# Processing Record 34 of Set 6 | beringovskiy
# Processing Record 35 of Set 6 | torbat-e jam
# Processing Record 36 of Set 6 | verkhoyansk
# Processing Record 37 of Set 6 | lorengau
# Processing Record 38 of Set 6 | muzhi
# Processing Record 39 of Set 6 | santa clara
# Processing Record 40 of Set 6 | yantal
# Processing Record 41 of Set 6 | masunga
# Processing Record 42 of Set 6 | wetaskiwin
# Processing Record 43 of Set 6 | coihaique
# Processing Record 44 of Set 6 | oktyabrskiy
# Processing Record 45 of Set 6 | mayor pablo lagerenza
# Processing Record 46 of Set 6 | beidao
# Processing Record 47 of Set 6 | upernavik
# Processing Record 48 of Set 6 | eureka
# Processing Record 49 of Set 6 | srednekolymsk
# Processing Record 1 of Set 7 | hagere hiywet
# marcona
# City not found. Skipping...
# Processing Record 2 of Set 7 | dubbo
# Processing Record 3 of Set 7 | linxia
# Processing Record 4 of Set 7 | namibe
# Processing Record 5 of Set 7 | axim
# Processing Record 6 of Set 7 | landeck
# Processing Record 7 of Set 7 | soyo
# Processing Record 8 of Set 7 | merauke
# Processing Record 9 of Set 7 | garden city
# Processing Record 10 of Set 7 | shumerlya
# Processing Record 11 of Set 7 | bayir
# Processing Record 12 of Set 7 | coahuayana
# Processing Record 13 of Set 7 | upington
# Processing Record 14 of Set 7 | mogadishu
# Processing Record 15 of Set 7 | tamasane
# Processing Record 16 of Set 7 | port lincoln
# Processing Record 17 of Set 7 | severo-kurilsk
# Processing Record 18 of Set 7 | raahe
# Processing Record 19 of Set 7 | neuquen
# Processing Record 20 of Set 7 | constitucion
# Processing Record 21 of Set 7 | salalah
# solovetskiy
# City not found. Skipping...
# umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 7 | baghdad
# Processing Record 23 of Set 7 | kontagora
# Processing Record 24 of Set 7 | balkhash
# Processing Record 25 of Set 7 | salym
# Processing Record 26 of Set 7 | ixcatepec
# Processing Record 27 of Set 7 | samarkand
# Processing Record 28 of Set 7 | la romana
# Processing Record 29 of Set 7 | itarema
# Processing Record 30 of Set 7 | finnsnes
# Processing Record 31 of Set 7 | durango
# Processing Record 32 of Set 7 | guacimo
# Processing Record 33 of Set 7 | bhola
# allanmyo
# City not found. Skipping...
# Processing Record 34 of Set 7 | ambilobe
# mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 7 | itaituba
# Processing Record 36 of Set 7 | kailua
# Processing Record 37 of Set 7 | mandera
# Processing Record 38 of Set 7 | imbituba
# Processing Record 39 of Set 7 | saint-pierre
# Processing Record 40 of Set 7 | nhulunbuy
# Processing Record 41 of Set 7 | salinopolis
# Processing Record 42 of Set 7 | rivne
# Processing Record 43 of Set 7 | peniche
# Processing Record 44 of Set 7 | imeni poliny osipenko
# Processing Record 45 of Set 7 | tarnova
# Processing Record 46 of Set 7 | bembereke
# Processing Record 47 of Set 7 | santa lucia
# Processing Record 48 of Set 7 | omboue
# Processing Record 49 of Set 7 | khorramshahr
# Processing Record 1 of Set 8 | malanje
# Processing Record 2 of Set 8 | gardabani
# Processing Record 3 of Set 8 | gorom-gorom
# samusu
# City not found. Skipping...
# Processing Record 4 of Set 8 | tazovskiy
# Processing Record 5 of Set 8 | fairbanks
# Processing Record 6 of Set 8 | gat
# Processing Record 7 of Set 8 | miles city
# Processing Record 8 of Set 8 | talara
# Processing Record 9 of Set 8 | dabat
# Processing Record 10 of Set 8 | annau
# bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 8 | ilulissat
# Processing Record 12 of Set 8 | lemon tree passage
# Processing Record 13 of Set 8 | xining
# Processing Record 14 of Set 8 | celestun
# Processing Record 15 of Set 8 | lanxi
# Processing Record 16 of Set 8 | dajal
# Processing Record 17 of Set 8 | jiwani
# Processing Record 18 of Set 8 | stornoway
# Processing Record 19 of Set 8 | bull savanna
# Processing Record 20 of Set 8 | megion
# Processing Record 21 of Set 8 | cochabamba
# Processing Record 22 of Set 8 | aasiaat
# Processing Record 23 of Set 8 | trairi
# Processing Record 24 of Set 8 | omsukchan
# Processing Record 25 of Set 8 | husavik
# Processing Record 26 of Set 8 | bremervorde
# Processing Record 27 of Set 8 | tabory
# Processing Record 28 of Set 8 | bintulu
# Processing Record 29 of Set 8 | sabang
# Processing Record 30 of Set 8 | pacific grove
# Processing Record 31 of Set 8 | nema
# Processing Record 32 of Set 8 | hithadhoo
# Processing Record 33 of Set 8 | egvekinot
# guicheng
# City not found. Skipping...
# Processing Record 34 of Set 8 | surgut
# Processing Record 35 of Set 8 | marawi
# Processing Record 36 of Set 8 | sambava
# Processing Record 37 of Set 8 | soligalich
# Processing Record 38 of Set 8 | sudak
# Processing Record 39 of Set 8 | alice springs
# Processing Record 40 of Set 8 | yenagoa
# ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | acapulco
# Processing Record 42 of Set 8 | komsomolskiy
# Processing Record 43 of Set 8 | hami
# Processing Record 44 of Set 8 | virginia beach
# Processing Record 45 of Set 8 | teguise
# Processing Record 46 of Set 8 | limon
# Processing Record 47 of Set 8 | ravar
# uwayl
# City not found. Skipping...
# Processing Record 48 of Set 8 | dunedin
# hihifo
# City not found. Skipping...
# Processing Record 49 of Set 8 | stolin
# Processing Record 1 of Set 9 | hualmay
# Processing Record 2 of Set 9 | bonavista
# Processing Record 3 of Set 9 | jaumave
# Processing Record 4 of Set 9 | kirakira
# Processing Record 5 of Set 9 | manokwari
# Processing Record 6 of Set 9 | hamilton
# Processing Record 7 of Set 9 | quatre cocos
# Processing Record 8 of Set 9 | zheleznodorozhnyy
# Processing Record 9 of Set 9 | hagi
# Processing Record 10 of Set 9 | mehamn
# Processing Record 11 of Set 9 | bubaque
# Processing Record 12 of Set 9 | te anau
# Processing Record 13 of Set 9 | kungurtug
# Processing Record 14 of Set 9 | miandrivazo
# kuche
# City not found. Skipping...
# Processing Record 15 of Set 9 | bud
# Processing Record 16 of Set 9 | baisha
# Processing Record 17 of Set 9 | sisimiut
# Processing Record 18 of Set 9 | ziro
# Processing Record 19 of Set 9 | kirkwall
# Processing Record 20 of Set 9 | vila franca do campo
# Processing Record 21 of Set 9 | weihe
# Processing Record 22 of Set 9 | puerto narino
# Processing Record 23 of Set 9 | fernley
# Processing Record 24 of Set 9 | tabatinga
# galgani
# City not found. Skipping...
# Processing Record 25 of Set 9 | lasa
# Processing Record 26 of Set 9 | mount pleasant
# monte cristi
# City not found. Skipping...
# sorvag
# City not found. Skipping...
# Processing Record 27 of Set 9 | hambantota
# Processing Record 28 of Set 9 | san quintin
# Processing Record 29 of Set 9 | rapar
# Processing Record 30 of Set 9 | awjilah
# Processing Record 31 of Set 9 | fort nelson
# Processing Record 32 of Set 9 | flin flon
# Processing Record 33 of Set 9 | batemans bay
# Processing Record 34 of Set 9 | pathein
# Processing Record 35 of Set 9 | bashtanka
# Processing Record 36 of Set 9 | promyshlennyy
# Processing Record 37 of Set 9 | mandalgovi
# Processing Record 38 of Set 9 | geraldton
# Processing Record 39 of Set 9 | nova olimpia
# Processing Record 40 of Set 9 | sinnamary
# Processing Record 41 of Set 9 | roma
# tabukiniberu
# City not found. Skipping...
# Processing Record 42 of Set 9 | verin
# tarudant
# City not found. Skipping...
# khomeynishahr
# City not found. Skipping...
# Processing Record 43 of Set 9 | tutoia
# Processing Record 44 of Set 9 | sungairaya
# Processing Record 45 of Set 9 | zabol
# Processing Record 46 of Set 9 | chake chake
# Processing Record 47 of Set 9 | kamenka
# Processing Record 48 of Set 9 | altay
# Processing Record 49 of Set 9 | kununurra
# Processing Record 1 of Set 10 | clyde river
# Processing Record 2 of Set 10 | ndjole
# Processing Record 3 of Set 10 | wladyslawowo
# Processing Record 4 of Set 10 | sao raimundo nonato
# Processing Record 5 of Set 10 | nelson bay
# Processing Record 6 of Set 10 | araci
# Processing Record 7 of Set 10 | bomet
# Processing Record 8 of Set 10 | auki
# Processing Record 9 of Set 10 | san andres
# Processing Record 10 of Set 10 | clemson
# Processing Record 11 of Set 10 | marzuq
# Processing Record 12 of Set 10 | loreto
# Processing Record 13 of Set 10 | labuhan
# Processing Record 14 of Set 10 | bulgan
# mudyuga
# City not found. Skipping...
# Processing Record 15 of Set 10 | namatanai
# Processing Record 16 of Set 10 | dakar
# Processing Record 17 of Set 10 | poum
# Processing Record 18 of Set 10 | yarada
# Processing Record 19 of Set 10 | kushima
# Processing Record 20 of Set 10 | gweta
# Processing Record 21 of Set 10 | grand gaube
# Processing Record 22 of Set 10 | bilma
# Processing Record 23 of Set 10 | gushikawa
# Processing Record 24 of Set 10 | yendi
# Processing Record 25 of Set 10 | gizo
# Processing Record 26 of Set 10 | misratah
# Processing Record 27 of Set 10 | vestmannaeyjar
# Processing Record 28 of Set 10 | sol-iletsk
# Processing Record 29 of Set 10 | the valley
# Processing Record 30 of Set 10 | young
# Processing Record 31 of Set 10 | adre
# Processing Record 32 of Set 10 | amahai
# Processing Record 33 of Set 10 | onalaska
# vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 10 | high level
# Processing Record 35 of Set 10 | mokhotlong
# Processing Record 36 of Set 10 | samarai
# Processing Record 37 of Set 10 | hervey bay
# Processing Record 38 of Set 10 | faya
# Processing Record 39 of Set 10 | elizabeth city
# Processing Record 40 of Set 10 | lembeni
# Processing Record 41 of Set 10 | saint-augustin
# Processing Record 42 of Set 10 | andenes
# Processing Record 43 of Set 10 | marsabit
# Processing Record 44 of Set 10 | tafalla
# Processing Record 45 of Set 10 | fengrun
# Processing Record 46 of Set 10 | rayong
# Processing Record 47 of Set 10 | ommen
# Processing Record 48 of Set 10 | porto nacional
# kerki
# City not found. Skipping...
# Processing Record 49 of Set 10 | rosario
# Processing Record 1 of Set 11 | mirnyy
# Processing Record 2 of Set 11 | yartsevo
# Processing Record 3 of Set 11 | monteagudo
# Processing Record 4 of Set 11 | san policarpo
# Processing Record 5 of Set 11 | ust-ilimsk
# Processing Record 6 of Set 11 | priladozhskiy
# dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 11 | windhoek
# Processing Record 8 of Set 11 | umm kaddadah
# Processing Record 9 of Set 11 | santa cruz del sur
# Processing Record 10 of Set 11 | belokurikha
# tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 11 | hoa binh
# Processing Record 12 of Set 11 | menongue
# Processing Record 13 of Set 11 | alta floresta
# Processing Record 14 of Set 11 | bonfim
# Processing Record 15 of Set 11 | riosucio
# Processing Record 16 of Set 11 | kimbe
# Processing Record 17 of Set 11 | anloga
# Processing Record 18 of Set 11 | benghazi
# Processing Record 19 of Set 11 | takoradi
# Processing Record 20 of Set 11 | lodeynoye pole
# Processing Record 21 of Set 11 | roseburg
# cumaribo
# City not found. Skipping...
# Processing Record 22 of Set 11 | mayumba
# Processing Record 23 of Set 11 | saint-joseph
# Processing Record 24 of Set 11 | emborion
# Processing Record 25 of Set 11 | gravdal
# Processing Record 26 of Set 11 | palapye
# Processing Record 27 of Set 11 | moerai
# Processing Record 28 of Set 11 | lubango
# Processing Record 29 of Set 11 | christchurch
# Processing Record 30 of Set 11 | formosa
# Processing Record 31 of Set 11 | baymak
# Processing Record 32 of Set 11 | washougal
# Processing Record 33 of Set 11 | along
# yanchukan
# City not found. Skipping...
# Processing Record 34 of Set 11 | luebo
# Processing Record 35 of Set 11 | veles
# Processing Record 36 of Set 11 | jalu
# Processing Record 37 of Set 11 | tiznit
# Processing Record 38 of Set 11 | kysyl-syr
# Processing Record 39 of Set 11 | westerly
# naftah
# City not found. Skipping...
# Processing Record 40 of Set 11 | lima
# Processing Record 41 of Set 11 | jacareacanga
# Processing Record 42 of Set 11 | shihezi
# bandar penggaram
# City not found. Skipping...
# Processing Record 43 of Set 11 | champerico
# Processing Record 44 of Set 11 | gombe
# Processing Record 45 of Set 11 | manadhoo
# Processing Record 46 of Set 11 | opatija
# Processing Record 47 of Set 11 | ambulu
# Processing Record 48 of Set 11 | xichang
# Processing Record 49 of Set 11 | dunda
# Processing Record 1 of Set 12 | tateyama
# Processing Record 2 of Set 12 | fort-shevchenko
# Processing Record 3 of Set 12 | saint marys
# Processing Record 4 of Set 12 | los llanos de aridane
# Processing Record 5 of Set 12 | riyadh
# suao
# City not found. Skipping...
# Processing Record 6 of Set 12 | tilichiki
# Processing Record 7 of Set 12 | hukuntsi
# Processing Record 8 of Set 12 | chigorodo
# Processing Record 9 of Set 12 | sokoni
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#convert to raw df

weather_dict = {
    "City": city_two,
    "Cloudiness": cloudinesses,
    "Country": countries,
    "Date": dates,
    "Humidity": humidities,
    "Lat": lats,
    "Lng": lngs,
    "Max Temp": max_temps,
    "Wind Speed": wind_speeds
}


weather_dataframe = pd.DataFrame(weather_dict)

# show the top of the dataframe
weather_dataframe.head(10)
# Out:
#          City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0    hermanus           4      ZA  1615667934        70 -34.4187   19.2345
# 1       nalut          92      LY  1615667779        46  30.3333   10.8500
# 2      hasaki          75      JP  1615667772        58  35.7333  140.8333
# 3    victoria          41      HK  1615667662        84  22.2855  114.1577
# 4     pangody          99      RU  1615667935        96  65.8500   74.4859
# 5  burns lake         100      CA  1615667935        49  54.2331 -125.7533
# 6    thompson          20      CA  1615667912        53  55.7435  -97.8558
# 7     lianran           0      CN  1615667936        71  24.9227  102.4850
# 8   santander          20      ES  1615667883        71  43.4647   -3.8044
# 9    souillac          40      MU  1615667936        78 -20.5167   57.5167
#
#    Max Temp  Wind Speed
# 0     72.00        3.00
# 1     60.85       20.78
# 2     51.80       11.50
# 3     70.00        1.99
# 4     -1.68       12.17
# 5     48.20       10.36
# 6     19.40       13.80
# 7     55.00        8.95
# 8     55.40       12.66
# 9     80.60        5.75

# %%
# Exporting to CSV

weather_dataframe.to_csv("weather_df.csv")

# Checking New DataFrame & Cleaning the Data

weather_data = pd.read_csv("weather_df.csv")
weather_df2 = weather_data.drop(columns=["Unnamed: 0"])
weather_df2.head(10)
# Out:
#          City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0    hermanus           4      ZA  1615667934        70 -34.4187   19.2345
# 1       nalut          92      LY  1615667779        46  30.3333   10.8500
# 2      hasaki          75      JP  1615667772        58  35.7333  140.8333
# 3    victoria          41      HK  1615667662        84  22.2855  114.1577
# 4     pangody          99      RU  1615667935        96  65.8500   74.4859
# 5  burns lake         100      CA  1615667935        49  54.2331 -125.7533
# 6    thompson          20      CA  1615667912        53  55.7435  -97.8558
# 7     lianran           0      CN  1615667936        71  24.9227  102.4850
# 8   santander          20      ES  1615667883        71  43.4647   -3.8044
# 9    souillac          40      MU  1615667936        78 -20.5167   57.5167
#
#    Max Temp  Wind Speed
# 0     72.00        3.00
# 1     60.85       20.78
# 2     51.80       11.50
# 3     70.00        1.99
# 4     -1.68       12.17
# 5     48.20       10.36
# 6     19.40       13.80
# 7     55.00        8.95
# 8     55.40       12.66
# 9     80.60        5.75

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
 #temp vs latitude scatterplot, format time

plt.scatter(weather_dataframe["Lat"], weather_dataframe["Max Temp"], marker='o',s=30, edgecolors= "black")
plt.title("City Latitude vs Max Temperature")

plt.ylim(0,100)
plt.xlim(-60, 80)

plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig("LAT VS TEMP.png")

##This graph shows that as you move closer to the equator the the maximum temperature increases and reduces as you move further away from the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#create a Scatter Plot for Lattitude vs Humidity
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Humidity"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity Level (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('LAT VS HUM.png')

##There is high variation in the humidity trend but we can interprete that the humidity is high within -5 and 5 degrees of latitude

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Cloudiness"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness Level (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('LAT VS CLOUD.png')

##There does not seem to be a clear relationship between the latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Wind Speed"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('LAT VS WIND.png')

##There does not seem to be a trend in city latitude and wind speed

# %% [markdown]
# ## Linear Regression

# %%
 #linear regression by hemisphere

# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dataframe.loc[weather_dataframe["Lat"]>0.01]
southern_hemisphere = weather_dataframe.loc[weather_dataframe["Lat"]<-0.01]

# northern_hemisphere.head()
southern_hemisphere.head()
# Out:
#                   City  Cloudiness Country        Date  Humidity      Lat  \
# 0             hermanus           4      ZA  1615667934        70 -34.4187
# 9             souillac          40      MU  1615667936        78 -20.5167
# 14  palmeiras de goias          85      BR  1615667939        88 -16.8050
# 18             mataura           3      NZ  1615667941        75 -46.1927
# 19             ushuaia          75      AR  1615667891        70 -54.8000
#
#          Lng  Max Temp  Wind Speed
# 0    19.2345     72.00        3.00
# 9    57.5167     80.60        5.75
# 14  -49.9258     76.19        2.93
# 18  168.8643     59.00        3.00
# 19  -68.3000     44.60       39.12

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Lattitude vs Temperature of City
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")

plt.ylim(0,100)
plt.xlim(0, 80)
plt.title(f'Northern Hemisphere - Max Temp vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')
plt.ylabel("Max. Temp")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("NORTH MAX TEMP VS LAT.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Lattitude vs Temperature of City (Southern Hemisphere)
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.ylim(30, 100)
plt.xlim(-60, 0, 10)
plt.title(f'Southern Hemisphere - Max Temp vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')
plt.ylabel("Max. Temp")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("SOUTH MAX TEMP VS LAT.png")

##Based on the two regression trends being opposite, it stands true that the temperature rises as you get closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title(f'Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')
plt.ylabel("Humidity")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("NORTH HUM VS LAT.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")

plt.ylim(0, 100)

plt.title(f'Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')
plt.ylabel("Humidity")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("SOUTH HUM VS LAT.png")

##There is a lot of scatter but it seems that in the southern hemi the humidity increases as you get closer to the equator
##The humidity decreases at lower atlitudes in the northn hemi

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.title(f'Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("NORTH CLOUD VS LAT.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")

plt.title(f'Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("SOUTH CLOUD VS LAT.png")

## There seems to be a lot of scatter to find a trend

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,22),fontsize=15,color="red")

plt.title(f'Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("NORTH WIND VS LAT.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")

plt.title(f'Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression {time.strftime("%m/%d/%Y")}')
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("SOUTH WIND VS LAT.png")

## Wind speed tends to be less than 10 mph except for extreme altitudes.
